# %% [markdown]
# # Exploratory Data Analysis

# %%
DATA_PATH = '../data'

# %%
import pandas as pd
import os

case_df = pd.read_csv(os.path.join(DATA_PATH, 'Case.csv'))
patient_info_df = pd.read_csv(os.path.join(DATA_PATH, 'PatientInfo.csv'))
policy_df = pd.read_csv(os.path.join(DATA_PATH, 'Policy.csv'))
region_df = pd.read_csv(os.path.join(DATA_PATH, 'Region.csv'))
time_df = pd.read_csv(os.path.join(DATA_PATH, 'Time.csv'))

# %% [markdown]
# ## Task 1.1
#
# Show policy type and duration average in days unit, then sort it descending

# %%
policy_df
# Out:
#     policy_id country            type                              gov_policy  \
# 0           1   Korea           Alert          Infectious Disease Alert Level
# 1           2   Korea           Alert          Infectious Disease Alert Level
# 2           3   Korea           Alert          Infectious Disease Alert Level
# 3           4   Korea           Alert          Infectious Disease Alert Level
# 4           5   Korea     Immigration           Special Immigration Procedure
# ..        ...     ...             ...                                     ...
# 56         57   Korea  Transformation                        Logistics center
# 57         58   Korea  Transformation                        Wearing of masks
# 58         59   Korea  Transformation                        Wearing of masks
# 59         60   Korea      Technology          KI-Pass: Korea Internet - Pass
# 60         61   Korea          Health  Extends Tightened Quarantine Measures
#
#                                                detail  start_date    end_date
# 0                                      Level 1 (Blue)  2020-01-03  2020-01-19
# 1                                    Level 2 (Yellow)  2020-01-20  2020-01-27
# 2                                    Level 3 (Orange)  2020-01-28  2020-02-22
# 3                                       Level 4 (Red)  2020-02-23         NaN
# 4                                          from China  2020-02-04         NaN
# ..                                                ...         ...         ...
# 56  On-site inspection of major logistics faciliti...  2020-05-29  2020-06-11
# 57  Mandatory wearing of passenger mask domestic, ...  2020-05-27         NaN
# 58  Drivers such as buses and taxis can refuse to ...  2020-05-26         NaN
# 59  new quick response (QR) code system this week ...  2020-06-10         NaN
# 60  Gov't Extends Tightened Quarantine Measures in...  2020-05-28  2020-06-14
#
# [61 rows x 7 columns]

# %%
policy_df['start_date'].isna().sum()
# Out:
# 0

# %%
policy_df['end_date'].isna().sum()
# Out:
# 37

# %% [markdown]
# Assume missing values are today date

# %%
from datetime import datetime

policy_df['end_date'].fillna(value=datetime.today().strftime('%Y-%m-%d'), inplace=True)

# %%
policy_df['end_date'].isna().sum()
# Out:
# 0

# %%
policy_df['start_date'] = pd.to_datetime(policy_df['start_date'])
policy_df['start_date']
# Out:
# 0    2020-01-03
# 1    2020-01-20
# 2    2020-01-28
# 3    2020-02-23
# 4    2020-02-04
#         ...
# 56   2020-05-29
# 57   2020-05-27
# 58   2020-05-26
# 59   2020-06-10
# 60   2020-05-28
# Name: start_date, Length: 61, dtype: datetime64[ns]

# %%
policy_df['end_date'] = pd.to_datetime(policy_df['end_date'])
policy_df['end_date']
# Out:
# 0    2020-01-19
# 1    2020-01-27
# 2    2020-02-22
# 3    2022-06-17
# 4    2022-06-17
#         ...
# 56   2020-06-11
# 57   2022-06-17
# 58   2022-06-17
# 59   2022-06-17
# 60   2020-06-14
# Name: end_date, Length: 61, dtype: datetime64[ns]

# %% [markdown]
# Apply mapping to get duration

# %%
policy_df['duration'] = (policy_df['end_date'] - policy_df['start_date']).map(lambda d: d.days)
policy_df['duration']
# Out:
# 0      16
# 1       7
# 2      25
# 3     845
# 4     864
#      ...
# 56     13
# 57    751
# 58    752
# 59    737
# 60     17
# Name: duration, Length: 61, dtype: int64

# %%
policy_mean_dur_df = policy_df[['type', 'duration']].groupby(by='type', as_index=False).mean().sort_values(by='duration', ascending=False)
policy_mean_dur_df
# Out:
#              type    duration
# 4     Immigration  828.333333
# 6      Technology  819.333333
# 3          Health  759.300000
# 7  Transformation  505.333333
# 5          Social  325.600000
# 0  Administrative  268.333333
# 1           Alert  223.250000
# 2       Education   95.866667

# %% [markdown]
# ## Task 1.2
#
# Get patient data count that lives in Seoul, then group it based on age and sex, finally sort them based on patient count ascending

# %%
patient_info_df
# Out:
#       patient_id     sex  age     country province         city  \
# 0     1000000001    male  50s       Korea    Seoul   Gangseo-gu
# 1     1000000002    male  30s       Korea    Seoul  Jungnang-gu
# 2     1000000003    male  50s       Korea    Seoul    Jongno-gu
# 3     1000000004    male  20s       Korea    Seoul      Mapo-gu
# 4     1000000005  female  20s       Korea    Seoul  Seongbuk-gu
# ...          ...     ...  ...         ...      ...          ...
# 5160  7000000015  female  30s       Korea  Jeju-do      Jeju-do
# 5161  7000000016     NaN  NaN       Korea  Jeju-do      Jeju-do
# 5162  7000000017     NaN  NaN  Bangladesh  Jeju-do      Jeju-do
# 5163  7000000018     NaN  NaN  Bangladesh  Jeju-do      Jeju-do
# 5164  7000000019     NaN  NaN  Bangladesh  Jeju-do      Jeju-do
#
#             infection_case infected_by contact_number symptom_onset_date  \
# 0          overseas inflow         NaN             75         2020-01-22
# 1          overseas inflow         NaN             31                NaN
# 2     contact with patient  2002000001             17                NaN
# 3          overseas inflow         NaN              9         2020-01-26
# 4     contact with patient  1000000002              2                NaN
# ...                    ...         ...            ...                ...
# 5160       overseas inflow         NaN             25                NaN
# 5161       overseas inflow         NaN            NaN                NaN
# 5162       overseas inflow         NaN             72                NaN
# 5163       overseas inflow         NaN            NaN                NaN
# 5164       overseas inflow         NaN            NaN                NaN
#
#      confirmed_date released_date deceased_date     state
# 0        2020-01-23    2020-02-05           NaN  released
# 1        2020-01-30    2020-03-02           NaN  released
# 2        2020-01-30    2020-02-19           NaN  released
# 3        2020-01-30    2020-02-15           NaN  released
# 4        2020-01-31    2020-02-24           NaN  released
# ...             ...           ...           ...       ...
# 5160     2020-05-30    2020-06-13           NaN  released
# 5161     2020-06-16    2020-06-24           NaN  released
# 5162     2020-06-18           NaN           NaN  isolated
# 5163     2020-06-18           NaN           NaN  isolated
# 5164     2020-06-18           NaN           NaN  isolated
#
# [5165 rows x 14 columns]

# %%
seoul_patient_df = patient_info_df[patient_info_df['province'] == 'Seoul']
seoul_patient_df
# Out:
#       patient_id     sex  age country province          city  \
# 0     1000000001    male  50s   Korea    Seoul    Gangseo-gu
# 1     1000000002    male  30s   Korea    Seoul   Jungnang-gu
# 2     1000000003    male  50s   Korea    Seoul     Jongno-gu
# 3     1000000004    male  20s   Korea    Seoul       Mapo-gu
# 4     1000000005  female  20s   Korea    Seoul   Seongbuk-gu
# ...          ...     ...  ...     ...      ...           ...
# 1307  1000001308     NaN  NaN   Korea    Seoul       Mapo-gu
# 1308  1000001309     NaN  NaN   Korea    Seoul       Mapo-gu
# 1309  1000001310     NaN  NaN   Korea    Seoul  Geumcheon-gu
# 1310  1000001311     NaN  NaN   Korea    Seoul           etc
# 1311  1000001312     NaN  NaN   Korea    Seoul  Eunpyeong-gu
#
#             infection_case infected_by contact_number symptom_onset_date  \
# 0          overseas inflow         NaN             75         2020-01-22
# 1          overseas inflow         NaN             31                NaN
# 2     contact with patient  2002000001             17                NaN
# 3          overseas inflow         NaN              9         2020-01-26
# 4     contact with patient  1000000002              2                NaN
# ...                    ...         ...            ...                ...
# 1307               Richway  1000001290            NaN                NaN
# 1308               Richway  1000001290            NaN                NaN
# 1309  contact with patient         NaN            NaN                NaN
# 1310                   NaN         NaN            NaN                NaN
# 1311                   NaN         NaN            NaN         2020-06-24
#
#      confirmed_date released_date deceased_date     state
# 0        2020-01-23    2020-02-05           NaN  released
# 1        2020-01-30    2020-03-02           NaN  released
# 2        2020-01-30    2020-02-19           NaN  released
# 3        2020-01-30    2020-02-15           NaN  released
# 4        2020-01-31    2020-02-24           NaN  released
# ...             ...           ...           ...       ...
# 1307     2020-06-29           NaN           NaN  isolated
# 1308     2020-06-29           NaN           NaN  isolated
# 1309     2020-06-29           NaN           NaN  isolated
# 1310     2020-06-29           NaN           NaN  isolated
# 1311     2020-06-29           NaN           NaN  isolated
#
# [1312 rows x 14 columns]

# %% [markdown]
# Check whether missing value of age and sex is the same data

# %%
(seoul_patient_df['age'].isna() == seoul_patient_df['sex'].isna()).unique()
# Out:
# array([ True])

# %% [markdown]
# Missing value of age and sex is the same data. Make it unknown, rather than NaN

# %%
seoul_patient_df['age'] = seoul_patient_df['age'].fillna('unknown')
seoul_patient_df['age'].isna().sum()
# Out:
# C:\Users\gunaw\AppData\Local\Temp\ipykernel_15628\3322595891.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seoul_patient_df['age'] = seoul_patient_df['age'].fillna('unknown')
# 0

# %%
seoul_patient_df['sex'] = seoul_patient_df['sex'].fillna('unknown')
seoul_patient_df['sex'].isna().sum()
# Out:
# C:\Users\gunaw\AppData\Local\Temp\ipykernel_15628\3726785871.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seoul_patient_df['sex'] = seoul_patient_df['sex'].fillna('unknown')
# 0

# %% [markdown]
# Make sure `patient_id` have no missing values and no duplicates.

# %%
seoul_patient_df['patient_id'].isna().sum(), seoul_patient_df['patient_id'].duplicated().sum()
# Out:
# (0, 0)

# %%
grouped_age_sex_df = seoul_patient_df[['age', 'sex', 'patient_id']].groupby(by=['age', 'sex'], as_index=False).count().sort_values(by='patient_id')
grouped_age_sex_df
# Out:
#         age      sex  patient_id
# 18      90s     male           2
# 1        0s     male           3
# 16      80s   female           4
# 0        0s   female           5
# 17      80s     male           6
# 15      70s     male          10
# 3       10s     male          13
# 2       10s   female          14
# 14      70s   female          16
# 13      60s     male          23
# 12      60s   female          24
# 9       40s     male          40
# 6       30s   female          42
# 8       40s   female          46
# 11      50s     male          46
# 7       30s     male          58
# 10      50s   female          67
# 5       20s     male          71
# 4       20s   female          94
# 19  unknown  unknown         728

# %% [markdown]
# Rename `patient_id` to `count`

# %%
grouped_age_sex_df.rename(columns=dict(patient_id='count'), inplace=True)
grouped_age_sex_df
# Out:
#         age      sex  count
# 18      90s     male      2
# 1        0s     male      3
# 16      80s   female      4
# 0        0s   female      5
# 17      80s     male      6
# 15      70s     male     10
# 3       10s     male     13
# 2       10s   female     14
# 14      70s   female     16
# 13      60s     male     23
# 12      60s   female     24
# 9       40s     male     40
# 6       30s   female     42
# 8       40s   female     46
# 11      50s     male     46
# 7       30s     male     58
# 10      50s   female     67
# 5       20s     male     71
# 4       20s   female     94
# 19  unknown  unknown    728

# %% [markdown]
# ## Task 1.3
